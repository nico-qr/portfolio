# %% [markdown]
# # NX TW An
#
# En este pequeño notebook analizamos unos datos

# %%
import networkx as nx

G = nx.read_edgelist("congress.edgelist")
print(G)
# Out:
# Graph with 475 nodes and 10222 edges

# %%
d = dict(G.degree)
nx.draw(G, nodelist = d.keys(), node_size = [v for v in d.values()])

# %%
m = max(d.values())

def get(val):
    for (key, value) in d.items():
        if val == value:
            return key
        
    return None
        
print(get(m))
# Out:
# 367
